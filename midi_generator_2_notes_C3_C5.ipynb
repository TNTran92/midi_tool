# %% [markdown]
# Uswe mypython39-midi venv for this workbook

# %%
import pandas as pd
#Import the random library  
import random 
 
# Generate a list of 20 keys out of 84 keys on the piano (88 total)
# https://inspiredacoustics.com/en/MIDI_note_numbers_and_center_frequencies
rand_list = []
for i in range (10):
    n=random.randint(23,106)
    rand_list.append(n)
print(rand_list)

def rand_choice():
    choice_list = [-2, -1,1,2]
    rand_choice1 = random.choice(choice_list)
    if rand_choice1 == -1:
        
        rand_choice2 = -2
    elif rand_choice1 == 1:
        rand_choice2 = 2
    elif rand_choice1 == 2:
        rand_choice2 = 1
    elif rand_choice1 == -2:
        rand_choice2 = -1
    return [rand_choice1, rand_choice2]

rand_choice_result = rand_choice()
#print(rand_choice_result[0])
#print(rand_choice_result[1])

# create a list of list of 4 items
# Item# 1: Pitch
# Item 2: That pitch of randomly higher or lower by one or half step
# Item 3: Pitch
# Item 4: That pitch of randomly higher or lower by one or half step depending on Item 2

rand_list_of_lists = []
for j in range(len(rand_list)):
    if j == 0:
        rand_choice_result = rand_choice()
        rand_list_of_lists = [[rand_list[j], rand_list[j]+rand_choice_result[0]]]
        print(rand_list_of_lists)
    else:
        rand_choice_result = rand_choice()
        rand_key = [rand_list[j], rand_list[j]+rand_choice_result[0]]
        rand_list_of_lists.append(rand_key)
print(rand_list_of_lists)

key_dict = {'72':'C5','71':'B4','70':'A#4/Bb4','69':'A4 concert pitch','68':'G#4/Ab4','67':'G4','66':'F#4/Gb4','65':'F4','64':'E4','63':'D#4/Eb4','62':'D4','61':'C#4/Db4','60':'C4 (middle C)','59':'B3','58':'A#3/Bb3','57':'A3','56':'G#3/Ab3','55':'G3','54':'F#3/Gb3','53':'F3','52':'E3','51':'D#3/Eb3','50':'D3','49':'C#3/Db3','48':'C3'}
answer_key = []
for k in range(len(rand_list_of_lists)):
    one_set = [key_dict[key] for key in list(map(str,rand_list_of_lists[k]))]
    answer_key.append(one_set)
print(answer_key)
# Out:
# [57, 81, 72, 103, 57, 31, 102, 64, 36, 98]
# [[57, 56]]
# [[57, 56], [81, 82], [72, 70], [103, 102], [57, 58], [31, 32], [102, 100], [64, 62], [36, 34], [98, 96]]
# [['A3', 'G#3/Ab3'], ['A5', 'A#5/Bb5'], ['C5', 'A#4/Bb4'], ['G7', 'F#7/Gb7'], ['A3', 'A#3/Bb3'], ['G1', 'G#1/Ab1'], ['F#7/Gb7', 'E7'], ['E4', 'D4'], ['C2', 'A#1/Bb1'], ['D7', 'C7']]

# %%
from midiutil.MidiFile import MIDIFile
import time
# Get the current Unix timestamp
current_timestamp = time.time()
import time
# Get the current Unix timestamp
current_timestamp = time.time()

def generate_midi(list_of_list):
    #create your MIDI object
    mf = MIDIFile(1)     # only 1 track
    track = 0   # the only track
def generate_midi(list_of_list):
    #create your MIDI object
    mf = MIDIFile(1)     # only 1 track
    track = 0   # the only track

    time = 0    # start at the beginning
    mf.addTrackName(track, time, "Sample Track")
    mf.addTempo(track, time, 110)

    # add some notes
    channel = 0
    volume = 100
    # add some notes
    channel = 0
    volume = 100

    time = 0
    duration_note = 1
    duration_set = 3

    for i in range(len(list_of_list)):
        for j in range(len(list_of_list[i])):
            if time == 0:
                pitch = list_of_list[i][j]
                mf.addNote(track, channel, pitch, time, duration_note, volume)
                time = time + duration_note + duration_note
            else:
                pitch = list_of_list[i][j]
                mf.addNote(track, channel, pitch, time, duration_note, volume)
                time = time + duration_note + duration_note
                if j == len(list_of_list[i]) - 1:
                    time = time + duration_set

    # write it to disk
    with open(f"output/output_2_note_{current_timestamp}.mid", 'wb') as outf:
        mf.writeFile(outf)
    with open(f"output/answer_key_output_2_note_{current_timestamp}.txt", 'w') as file:
        # Write each item in answer_key
        for item in answer_key:
            file.write(f"{item}\n")
    print("Done")
generate_midi(rand_list_of_lists)
# Out:
# Done
